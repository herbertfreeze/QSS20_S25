# %%
pip install pandas openpyxl
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
df = pd.read_excel('superyacht.xlsx', sheet_name='YachtOwners', engine='openpyxl')

# %%
df.head(20)
# Out:
#             Name Name 2                Added Motor/Sail        length  \
# 0            818    NaN                  NaN      Motor   77m (253ft)
# 1       24 Karat    NaN                  NaN    Motor     32m (106ft)
# 2            4US    NaN             march-23      Motor   43m (141ft)
# 3           4YOU    NaN                  NaN    Motor     47m (154ft)
# 4           4You    NaN                  NaN    Motor     54m (178ft)
# 5       60 Years    NaN                  NaN       Sail   46m (150ft)
# 6              A    NaN                  NaN    Motor    119m (390ft)
# 7        A and A    NaN  2021-11-01 00:00:00      Motor   45m (147ft)
# 8     A+ / Topaz    NaN                  NaN    Motor    147m (483ft)
# 9             A2    NaN                  NaN    Motor     41m (135ft)
# 10           AAA    NaN   sold to Toto Wolff      Motor   50m (164ft)
# 11         Aalto    NaN                  NaN    Motor     80m (262ft)
# ...

# %% [markdown]
# # OFFSHORE DATASET

# %%
df = pd.read_csv('nodes-addresses.csv')
df.head(20)
# Out:
#      node_id                                            address name  \
# 0   24000001  ANNEX FREDERICK & SHIRLEY STS, P.O. BOX N-4805...  NaN
# 1   24000002  SUITE E-2,UNION COURT BUILDING, P.O. BOX N-818...  NaN
# 2   24000003  LYFORD CAY HOUSE, LYFORD CAY, P.O. BOX N-7785,...  NaN
# 3   24000004  P.O. BOX N-3708 BAHAMAS FINANCIAL CENTRE, P.O....  NaN
# 4   24000005  LYFORD CAY HOUSE, 3RD FLOOR, LYFORD CAY, P.O. ...  NaN
# 5   24000006  303 SHIRLEY STREET, P.O. BOX N-492, NASSAU, BA...  NaN
# 6   24000007  OCEAN CENTRE, MONTAGU FORESHORE, P.O. BOX SS-1...  NaN
# 7   24000008  PROVIDENCE HOUSE, EAST WING EAST HILL ST, P.O....  NaN
# 8   24000009  BAYSIDE EXECUTIVE PARK, WEST BAY & BLAKE, P.O....  NaN
# 9   24000010  GROUND FLOOR, GOODMAN'S BAY CORPORATE CE, P.O....  NaN
# 10  24000011  TK HOUSE, BAYSIDE EXECUTIVE PARK, P.O. BOX AP-...  NaN
# 11  24000012  BAYSIDE HOUSE WEST BAY & BLAKE ROAD, P.O. BOX ...  NaN
# 12  24000013  #308 EAST BAY ST. 4TH FLOOR, P.O. BOX N-7768, ...  NaN
# ...

# %%
df = pd.read_csv('nodes-entities.csv')
df.head(20)
# Out:
# /var/folders/4p/1hb6xh85081_hpl5qx7hz9fr0000gn/T/ipykernel_20898/1775839493.py:1: DtypeWarning: Columns (2,3,6,7,10,11,12,13,14,15,16,17,20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('nodes-entities.csv')
#      node_id                                          name  \
# 0   10000001      TIANSHENG INDUSTRY AND TRADING CO., LTD.
# 1   10000002   NINGBO SUNRISE ENTERPRISES UNITED CO., LTD.
# 2   10000003                            HOTFOCUS CO., LTD.
# 3   10000004               SKY-BLUE GIFTS & TOYS CO., LTD.
# 4   10000005          FORTUNEMAKER INVESTMENTS CORPORATION
# 5   10000006                          8808 HOLDING LIMITED
# 6   10000007                      KENT DEVELOPMENT LIMITED
# 7   10000008                           BONUS TRADE LIMITED
# 8   10000009                                AMARANDAN LTD.
# 9   10000010                              NEW IDEA LIMITED
# 10  10000011                            HUGH POWER LIMITED
# ...

# %%
df = pd.read_csv('nodes-intermediaries.csv')
df.head(20)
# Out:
#      node_id                                 name                  status  \
# 0   11000001              MICHAEL PAPAGEORGE, MR.                  ACTIVE
# 1   11000002                   CORFIDUCIA ANSTALT                  ACTIVE
# 2   11000003                        DAVID, RONALD               SUSPENDED
# 3   11000004           DE  BOUTSELIS, JEAN-PIERRE               SUSPENDED
# 4   11000005             THE LEVANT LAWYERS (TLL)                  ACTIVE
# 5   11000006                    ABARTH, ANNELIESE  UNRECOVERABLE ACCOUNTS
# 6   11000007                  FIGEST CONSEIL S.A.                  ACTIVE
# 7   11000008                    MED ENERGY S.A.L.                  ACTIVE
# 8   11000009               TRUSTCO LABUAN SDN BHD               SUSPENDED
# 9   11000010                SYL LOGIC SERVICES SA                  ACTIVE
# 10  11000011                   LAFEVER, RONALD L.               SUSPENDED
# 11  11000012                BROUGH, CHARLES (MR.)                INACTIVE
# ...

# %%
df = pd.read_csv('nodes-officers.csv')
df.head(20)
# Out:
#      node_id                               name    countries country_codes  \
# 0   12000001                         KIM SOO IN  South Korea           KOR
# 1   12000002                          Tian Yuan        China           CHN
# 2   12000003               GREGORY JOHN SOLOMON    Australia           AUS
# 3   12000004                     MATSUDA MASUMI        Japan           JPN
# 4   12000005                        HO THUY NGA     Viet Nam           VNM
# 5   12000006                     RACHMAT ARIFIN    Australia           AUS
# 6   12000007                        TAN SUN-HUA  Philippines           PHL
# 7   12000008      Ou Yang Yet-Sing and Chang Ko       Taiwan           TWN
# 8   12000009  Wu Chi-Ping and Wu Chou Tsan-Ting       Taiwan           TWN
# 9   12000010                      ZHONG LI MING        China           CHN
# 10  12000011                           LIN PING        China           CHN
# ...

# %%
df = pd.read_csv('nodes-others.csv')
df.head(20)
# Out:
#      node_id                                   name  \
# 0   85004929                 ANTAM ENTERPRISES N.V.
# 1   85008443                         DEVIATION N.V.
# 2   85008517                            ARIAZI N.V.
# 3   85008542                          FLAIRUBA N.V.
# 4   85008583      S.L. ARUBA FISHERIES TRADING N.V.
# 5   85008632                     PALCOHI ARUBA N.V.
# 6   85008634                   CHEECHO (ARUBA) N.V.
# 7   85008647                      WINTERGARDEN N.V.
# 8   85008675                 CRUKEL (ARUBA) II N.V.
# 9   85008706                         CARAMBOLA N.V.
# 10  85008794                      BEACH BUM CO N.V.
# 11  85008888                       DE LANDAUER N.V.
# 12  85009016                     RUPCHAND SONS N.V.
# 13  85009035            ASSANG TRADING COMPANY N.V.
# 14  85009054             RED SAIL SPORTS ARUBA N.V.
# 15  85009128                   DEALS ON WHEELS N.V.
# 16  85009129                          JAVARUBA N.V.
# ...

# %%
df = pd.read_csv('relationships.csv')
df.head(20)
# Out:
# /var/folders/4p/1hb6xh85081_hpl5qx7hz9fr0000gn/T/ipykernel_20898/4207579605.py:1: DtypeWarning: Columns (4,5,6,7) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('relationships.csv')
#     node_id_start  node_id_end            rel_type                link status  \
# 0        10002580     14106952  registered_address  registered address    NaN
# 1        10004460     14101133  registered_address  registered address    NaN
# 2        10023813     14105100  registered_address  registered address    NaN
# 3        10023840     14100712  registered_address  registered address    NaN
# 4        10010428     14093957  registered_address  registered address    NaN
# 5        10012916     14093957  registered_address  registered address    NaN
# 6        10016348     14091822  registered_address  registered address    NaN
# 7        10016353     14092974  registered_address  registered address    NaN
# ...
