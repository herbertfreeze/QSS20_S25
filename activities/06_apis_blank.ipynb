# %%
## imports
import pandas as pd
import numpy as np
import re
import requests
import yaml


## repeated printouts
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# # 1. Example 1: no credentials; no wrapper
#
# Site: National Assessment of Education Progress (NAEP)
#
# Documentation: https://www.nationsreportcard.gov/api_documentation.aspx
#
# Base link: https://www.nationsreportcard.gov/DataService/GetAdhocData.aspx

# %% [markdown]
# ## 1.1 Query to pull some data

# %%
## using their example query of 2011 writing scores separated by gender
## based on here - https://stackoverflow.com/questions/40836749/pythonic-way-of-writing-a-single-line-long-string
## using the ( ) syntax to formulate a long
## string without linebreaks added
example_naep_query = (
'https://www.nationsreportcard.gov/'
'Dataservice/GetAdhocData.aspx?'
'type=data&subject=writing&grade=8&'
'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011')


example_naep_query
# Out:
# 'https://www.nationsreportcard.gov/Dataservice/GetAdhocData.aspx?type=data&subject=writing&grade=8&subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011'

# %%
## use requests to call the api
naep_resp = requests.get(example_naep_query)
naep_resp
print(type(naep_resp))

## get the json contents of the response 
## here, we're assuming valid response
naep_resp_j = naep_resp.json()
naep_resp_j

## with result, turn it into a dataframe
naep_resp_d = pd.DataFrame(naep_resp_j['result'])
naep_resp_d
# Out:
# <Response [200]>
# <class 'requests.models.Response'>
# {'status': 200,
#  'serviceVersion': '3.28.2025.1',
#  'dwellTimeMS': '15.6214',
#  'avgWebHostCPUTotalLoad': 'N/A',
#  'dataHitType': 'FROM_MEMORY',
#  'Source': 'B11B',
#  'result': [{'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 2,
#    'CohortLabel': 'Grade 8',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 8,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Gender',
#    'varValue': '1',
#    'varValueLabel': 'Male',
#    'value': 139.099504632971,
#    'isStatDisplayable': 1,
#    'errorFlag': 0},
#   {'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 2,
#    'CohortLabel': 'Grade 8',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 8,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Gender',
#    'varValue': '2',
#    'varValueLabel': 'Female',
#    'value': 158.567104984955,
#    'isStatDisplayable': 1,
#    'errorFlag': 0}]}
#    year sample yearSampleLabel  Cohort CohortLabel stattype subject  grade  \
# 0  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
# 1  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
#
#    scale jurisdiction       jurisLabel variable variableLabel varValue  \
# 0  WRIRP           NP  National public   GENDER        Gender        1
# 1  WRIRP           NP  National public   GENDER        Gender        2
#
#   varValueLabel       value  isStatDisplayable  errorFlag
# 0          Male  139.099505                  1          0
# 1        Female  158.567105                  1          0

# %%
for i in range(5):
    print("Our current number is {}, the next is {}".format(i, i+1))
# Out:
# Our current number is 0, the next is 1
# Our current number is 1, the next is 2
# Our current number is 2, the next is 3
# Our current number is 3, the next is 4
# Our current number is 4, the next is 5

# %% [markdown]
# ## 1.2 What happens if there's an error in our query?

# %%
## here's a query that from the documentation we know
## won't work since i modified year to 2025 which doesnt
## exist in the data
wrong_naep_query = (
'https://www.nationsreportcard.gov/'
'Dataservice/GetAdhocData.aspx?'
'type=data&subject=writing&grade=8&'
'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2025')

wrong_naep_query
# Out:
# 'https://www.nationsreportcard.gov/Dataservice/GetAdhocData.aspx?type=data&subject=writing&grade=8&subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2028'

# %%
## use requests to call the api
naep_wrong_resp = requests.get(wrong_naep_query)
naep_wrong_resp
# Out:
# <Response [400]>

# %%
## in the case of this particular api,
## the call returns some response but
## when we try to extract the json containing
## status or results, we get in an error
#naep_wrong_resp.json() # uncomment to see error

# %% [markdown]
# ### 1.2.2 More all-purpose way of allowing remainder of calls to run: try, except

# %%
## putting it in a try; except as general error catching
try:
    results = naep_wrong_resp.json()['result']
except Exception as e:
    print('Failed to get result from API due to error:')
    print(e) # or just: pass
# Out:
# Failed to get result from API due to error:
# Invalid control character at: line 1 column 293 (char 292)

# %% [markdown]
# ### 1.2.3 Can usually also find more targeted way but that varies more across APIs

# %%
## if we wanted do more specific error catching,
## see that the status == 400 actually appears here
## so could write if else along those lines
naep_wrong_resp.text
naep_resp.text

if "System.Exception" in naep_wrong_resp.text:
    print("NAEP results not found")
# Out:
# '{"statusCode":400,"result": "System.Exception: The query \'SELECT DISTINCT Framework FROM Cycles WHERE Subject=\'WRI\' AND Cohort=2 AND CONVERT(VARCHAR(10),Year)+Sample IN (\'2028R3\')\' did not return exactly 1 framework. Make sure you can trend the years defined for the given subject and cohort.\r\n   at NRCDataService3.GetAdhocData.GetFramework(NDEContext& ndeContext, String subjectCode, List`1 yearSamples, String cohort) in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 2547\r\n   at NRCDataService3.GetAdhocData.PopulateBaseOrchestratorRequest() in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 2168\r\n   at NRCDataService3.GetAdhocData.ConstructRequest_Datapoint() in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 807\r\n   at NRCDataService3.GetAdhocData.Page_Load(Object sender, EventArgs e) in C:\\projects\\ndecore2015\\NRCDataService2\\GetAdhocData.aspx.cs:line 261"}'
# '{"status":200,"serviceVersion":"3.28.2025.1","dwellTimeMS":"15.6214","avgWebHostCPUTotalLoad":"N/A","dataHitType":"FROM_MEMORY","Source":"B11B","result": [{"year":2011,"sample":"R3","yearSampleLabel":"2011","Cohort":2,"CohortLabel":"Grade 8","stattype":"MN:MN","subject":"WRI","grade":8,"scale":"WRIRP","jurisdiction":"NP","jurisLabel":"National public","variable":"GENDER","variableLabel":"Gender","varValue":"1","varValueLabel":"Male","value":139.099504632971,"isStatDisplayable":1,"errorFlag":0},{"year":2011,"sample":"R3","yearSampleLabel":"2011","Cohort":2,"CohortLabel":"Grade 8","stattype":"MN:MN","subject":"WRI","grade":8,"scale":"WRIRP","jurisdiction":"NP","jurisLabel":"National public","variable":"GENDER","variableLabel":"Gender","varValue":"2","varValueLabel":"Female","value":158.567104984955,"isStatDisplayable":1,"errorFlag":0}]}'
# NAEP results not found

# %% [markdown]
# ## Activity 1: writing a function to make multiple, sequential calls
#
# - Say we want to pull the data for grades 4, 8, and 12
# - How can we write a function that iterates over a list of those grades and pulls the data for each grade?
#
# **Note**: an ideal function would have arguments for each parameter in the API like subject, subscale, etc. Here we can leave those other parts constant

# %%
# your code here

# %%
# your code here

grades = ['4','8','12']

R = []

for grade in grades: 
    example_naep_query = (
        'https://www.nationsreportcard.gov/'
        'Dataservice/GetAdhocData.aspx?'
        f'type=data&subject=writing&grade={grade}&'
        'subscale=WRIRP&variable=GENDER&jurisdiction=NP&stattype=MN:MN&Year=2011')
    naep_resp = requests.get(example_naep_query)
    
    try: 
        naep_resp_j = naep_resp.json()
        naep_resp_j
        naep_resp_d = pd.DataFrame(naep_resp_j['result'])
        # result = pd.concat([result,naep_resp_d]) 
        R.append(naep_resp_d)
    
    except Exception as e:
        print(e)
        
pd.concat(R)
# Out:
# Invalid control character at: line 1 column 293 (char 292)
# {'status': 200,
#  'serviceVersion': '3.28.2025.1',
#  'dwellTimeMS': '0',
#  'avgWebHostCPUTotalLoad': 'N/A',
#  'dataHitType': 'FROM_MEMORY',
#  'Source': 'B11B',
#  'result': [{'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 2,
#    'CohortLabel': 'Grade 8',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 8,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Gender',
#    'varValue': '1',
#    'varValueLabel': 'Male',
#    'value': 139.099504632971,
#    'isStatDisplayable': 1,
#    'errorFlag': 0},
#   {'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 2,
#    'CohortLabel': 'Grade 8',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 8,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Gender',
#    'varValue': '2',
#    'varValueLabel': 'Female',
#    'value': 158.567104984955,
#    'isStatDisplayable': 1,
#    'errorFlag': 0}]}
# {'status': 200,
#  'serviceVersion': '3.28.2025.1',
#  'dwellTimeMS': '0',
#  'avgWebHostCPUTotalLoad': 'N/A',
#  'dataHitType': 'FROM_MEMORY',
#  'Source': 'B11B',
#  'result': [{'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 3,
#    'CohortLabel': 'Grade 12',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 12,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Gender',
#    'varValue': '1',
#    'varValueLabel': 'Male',
#    'value': 141.256977963264,
#    'isStatDisplayable': 1,
#    'errorFlag': 0},
#   {'year': 2011,
#    'sample': 'R3',
#    'yearSampleLabel': '2011',
#    'Cohort': 3,
#    'CohortLabel': 'Grade 12',
#    'stattype': 'MN:MN',
#    'subject': 'WRI',
#    'grade': 12,
#    'scale': 'WRIRP',
#    'jurisdiction': 'NP',
#    'jurisLabel': 'National public',
#    'variable': 'GENDER',
#    'variableLabel': 'Gender',
#    'varValue': '2',
#    'varValueLabel': 'Female',
#    'value': 155.385916780351,
#    'isStatDisplayable': 1,
#    'errorFlag': 0}]}
#    year sample yearSampleLabel  Cohort CohortLabel stattype subject  grade  \
# 0  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
# 1  2011     R3            2011       2     Grade 8    MN:MN     WRI      8
# 0  2011     R3            2011       3    Grade 12    MN:MN     WRI     12
# 1  2011     R3            2011       3    Grade 12    MN:MN     WRI     12
#
#    scale jurisdiction       jurisLabel variable variableLabel varValue  \
# 0  WRIRP           NP  National public   GENDER        Gender        1
# 1  WRIRP           NP  National public   GENDER        Gender        2
# 0  WRIRP           NP  National public   GENDER        Gender        1
# 1  WRIRP           NP  National public   GENDER        Gender        2
#
#   varValueLabel       value  isStatDisplayable  errorFlag
# 0          Male  139.099505                  1          0
# 1        Female  158.567105                  1          0
# 0          Male  141.256978                  1          0
# 1        Female  155.385917                  1          0

# %% [markdown]
# # 2. Example 2: needs credentials; no wrapper

# %% [markdown]
# Create an account here: https://www.yelp.com/developers/v3/manage_app

# %%
## get the key
API_KEY = "PASTE KEY HERE"

# %%
## use documentation to define what to search
## doc: https://www.yelp.com/developers/documentation/v3/business_search
## write the query 
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "restaurants"
my_location = "Hanover,NH,03755"
yelp_genquery = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location)

## use requests to call the API; here, we're
## passing it our credentials (structure varies
## by API and telling it to only return 10 results
## (max is 50 at once)
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp = requests.get(yelp_genquery, headers = header)
yelp_genresp

## then, look at structure of response
yelp_genjson = yelp_genresp.json()
# Out:
# <Response [200]>

# %%
yelp_genjson['businesses'][0]
# Out:
# {'id': 'wyV_NfYn4ZOfp_sHMDPcAw',
#  'alias': 'bistro-at-six-hanover',
#  'name': 'Bistro at Six',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i4jvssUsxa79VYVLOD3TmQ/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/bistro-at-six-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#  'review_count': 2,
#  'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#   {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#   {'alias': 'tradamerican', 'title': 'American'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 43.7001146, 'longitude': -72.2877078},
#  'transactions': [],
#  'price': '$$',
#  'location': {'address1': '6 E South St',
#   'address2': None,
#   'address3': '',
#   'city': 'Hanover',
#   'zip_code': '03755',
#   'country': 'US',
#   'state': 'NH',
#   'display_address': ['6 E South St', 'Hanover, NH 03755']},
#  'phone': '+16036430600',
#  'display_phone': '(603) 643-0600',
#  'distance': 198.65178837196856}

# %%
## example business
yelp_genjson['businesses'][0]

## more automatic way of summarizing but things end up in lists
## within columns for things like categories
yelp_gendf = pd.DataFrame(yelp_genjson['businesses'])
yelp_gendf.head()
# Out:
# {'id': 'wyV_NfYn4ZOfp_sHMDPcAw',
#  'alias': 'bistro-at-six-hanover',
#  'name': 'Bistro at Six',
#  'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/i4jvssUsxa79VYVLOD3TmQ/o.jpg',
#  'is_closed': False,
#  'url': 'https://www.yelp.com/biz/bistro-at-six-hanover?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#  'review_count': 2,
#  'categories': [{'alias': 'lounges', 'title': 'Lounges'},
#   {'alias': 'cocktailbars', 'title': 'Cocktail Bars'},
#   {'alias': 'tradamerican', 'title': 'American'}],
#  'rating': 4.0,
#  'coordinates': {'latitude': 43.7001146, 'longitude': -72.2877078},
#  'transactions': [],
#  'price': '$$',
#  'location': {'address1': '6 E South St',
#   'address2': None,
#   'address3': '',
#   'city': 'Hanover',
#   'zip_code': '03755',
#   'country': 'US',
#   'state': 'NH',
#   'display_address': ['6 E South St', 'Hanover, NH 03755']},
#  'phone': '+16036430600',
#  'display_phone': '(603) 643-0600',
#  'distance': 198.65178837196856}
#                        id                               alias  \
# 0  wyV_NfYn4ZOfp_sHMDPcAw               bistro-at-six-hanover
# 1  XVGEEIH5rVB2QzW-qywcJw              base-camp-cafe-hanover
# 2  8ybF6YyRldtZmU9jil4xlg   mollys-restaurant-and-bar-hanover
# 3  KA8yhrd-ClVYMyOefXdVYg  lous-restaurant-and-bakery-hanover
# 4  5WW4g_LRwau29KyjZGLyAA            sawtooth-kitchen-hanover
#
#                         name  \
# 0              Bistro at Six
# 1             Base Camp Cafe
# 2   Molly's Restaurant & Bar
# 3  Lou's Restaurant & Bakery
# 4           Sawtooth Kitchen
#
#                                            image_url  is_closed  \
# 0  https://s3-media2.fl.yelpcdn.com/bphoto/i4jvss...      False
# 1  https://s3-media1.fl.yelpcdn.com/bphoto/p8_YiE...      False
# 2  https://s3-media4.fl.yelpcdn.com/bphoto/TJLrrA...      False
# 3  https://s3-media3.fl.yelpcdn.com/bphoto/VAx8H9...      False
# 4  https://s3-media3.fl.yelpcdn.com/bphoto/61MNG4...      False
#
#                                                  url  review_count  \
# 0  https://www.yelp.com/biz/bistro-at-six-hanover...             2
# 1  https://www.yelp.com/biz/base-camp-cafe-hanove...           256
# 2  https://www.yelp.com/biz/mollys-restaurant-and...           561
# 3  https://www.yelp.com/biz/lous-restaurant-and-b...           430
# 4  https://www.yelp.com/biz/sawtooth-kitchen-hano...            30
#
#                                           categories  rating  \
# 0  [{'alias': 'lounges', 'title': 'Lounges'}, {'a...     4.0
# 1  [{'alias': 'himalayan', 'title': 'Himalayan/Ne...     4.4
# 2  [{'alias': 'tradamerican', 'title': 'American'...     3.9
# 3  [{'alias': 'tradamerican', 'title': 'American'...     4.2
# 4  [{'alias': 'chickenshop', 'title': 'Chicken Sh...     4.2
#
#                                          coordinates transactions price  \
# 0  {'latitude': 43.7001146, 'longitude': -72.2877...           []    $$
# 1  {'latitude': 43.700626, 'longitude': -72.2887803}   [delivery]    $$
# 2  {'latitude': 43.701144, 'longitude': -72.2894249}   [delivery]    $$
# 3    {'latitude': 43.70143, 'longitude': -72.289001}   [delivery]    $$
# 4    {'latitude': 43.70158, 'longitude': -72.289641}           []   NaN
#
#                                             location         phone  \
# 0  {'address1': '6 E South St', 'address2': None,...  +16036430600
# 1  {'address1': '3 Lebanon St', 'address2': 'Ste ...  +16036432007
# 2  {'address1': '43 South Main St', 'address2': '...  +16036432570
# 3  {'address1': '30 S Main St', 'address2': '', '...  +16036433321
# 4  {'address1': '33 S Main St', 'address2': '', '...  +16036435134
#
#     display_phone    distance
# 0  (603) 643-0600  198.651788
# 1  (603) 643-2007  196.139758
# 2  (603) 643-2570  250.830160
# 3  (603) 643-3321  245.079232
# 4  (603) 643-5134  242.607552

# %%
## more data-specific way of summarizing
## we're doing a simple approach and just retaining
## cols that have a simple str structure
## if doing for real, would want to extract things
def clean_yelp_json(one_biz):

    ## restrict to str cols
    d_str = {key:value for key, value in one_biz.items()
             if type(value) == str}
    
    df_str = pd.DataFrame(d_str, index = [d_str['id']])
    return(df_str)

yelp_stronly = [clean_yelp_json(one_b) for one_b in yelp_genjson['businesses']]
yelp_stronly_df = pd.concat(yelp_stronly)

yelp_stronly_df.head(7)
# Out:
#                                             id  \
# wyV_NfYn4ZOfp_sHMDPcAw  wyV_NfYn4ZOfp_sHMDPcAw
# XVGEEIH5rVB2QzW-qywcJw  XVGEEIH5rVB2QzW-qywcJw
# 8ybF6YyRldtZmU9jil4xlg  8ybF6YyRldtZmU9jil4xlg
# KA8yhrd-ClVYMyOefXdVYg  KA8yhrd-ClVYMyOefXdVYg
# 5WW4g_LRwau29KyjZGLyAA  5WW4g_LRwau29KyjZGLyAA
# neBEWvgHNhsXIBImCYx_6A  neBEWvgHNhsXIBImCYx_6A
# 34j_2nRCVQBTKafJvncZlg  34j_2nRCVQBTKafJvncZlg
#
#                                                      alias  \
# wyV_NfYn4ZOfp_sHMDPcAw               bistro-at-six-hanover
# XVGEEIH5rVB2QzW-qywcJw              base-camp-cafe-hanover
# 8ybF6YyRldtZmU9jil4xlg   mollys-restaurant-and-bar-hanover
# KA8yhrd-ClVYMyOefXdVYg  lous-restaurant-and-bakery-hanover
# 5WW4g_LRwau29KyjZGLyAA            sawtooth-kitchen-hanover
# neBEWvgHNhsXIBImCYx_6A       murphy-s-on-the-green-hanover
# 34j_2nRCVQBTKafJvncZlg           pine-restaurant-hanover-2
#
#                                              name  \
# wyV_NfYn4ZOfp_sHMDPcAw              Bistro at Six
# XVGEEIH5rVB2QzW-qywcJw             Base Camp Cafe
# 8ybF6YyRldtZmU9jil4xlg   Molly's Restaurant & Bar
# KA8yhrd-ClVYMyOefXdVYg  Lou's Restaurant & Bakery
# 5WW4g_LRwau29KyjZGLyAA           Sawtooth Kitchen
# neBEWvgHNhsXIBImCYx_6A      Murphy’s on the Green
# 34j_2nRCVQBTKafJvncZlg            PINE Restaurant
#
#                                                                 image_url  \
# wyV_NfYn4ZOfp_sHMDPcAw  https://s3-media2.fl.yelpcdn.com/bphoto/i4jvss...
# XVGEEIH5rVB2QzW-qywcJw  https://s3-media1.fl.yelpcdn.com/bphoto/p8_YiE...
# 8ybF6YyRldtZmU9jil4xlg  https://s3-media4.fl.yelpcdn.com/bphoto/TJLrrA...
# KA8yhrd-ClVYMyOefXdVYg  https://s3-media3.fl.yelpcdn.com/bphoto/VAx8H9...
# 5WW4g_LRwau29KyjZGLyAA  https://s3-media3.fl.yelpcdn.com/bphoto/61MNG4...
# neBEWvgHNhsXIBImCYx_6A  https://s3-media2.fl.yelpcdn.com/bphoto/76DCQr...
# 34j_2nRCVQBTKafJvncZlg  https://s3-media3.fl.yelpcdn.com/bphoto/c2SgUR...
#
#                                                                       url  \
# wyV_NfYn4ZOfp_sHMDPcAw  https://www.yelp.com/biz/bistro-at-six-hanover...
# XVGEEIH5rVB2QzW-qywcJw  https://www.yelp.com/biz/base-camp-cafe-hanove...
# 8ybF6YyRldtZmU9jil4xlg  https://www.yelp.com/biz/mollys-restaurant-and...
# KA8yhrd-ClVYMyOefXdVYg  https://www.yelp.com/biz/lous-restaurant-and-b...
# 5WW4g_LRwau29KyjZGLyAA  https://www.yelp.com/biz/sawtooth-kitchen-hano...
# neBEWvgHNhsXIBImCYx_6A  https://www.yelp.com/biz/murphy-s-on-the-green...
# 34j_2nRCVQBTKafJvncZlg  https://www.yelp.com/biz/pine-restaurant-hanov...
#
#                        price         phone   display_phone
# wyV_NfYn4ZOfp_sHMDPcAw    $$  +16036430600  (603) 643-0600
# XVGEEIH5rVB2QzW-qywcJw    $$  +16036432007  (603) 643-2007
# 8ybF6YyRldtZmU9jil4xlg    $$  +16036432570  (603) 643-2570
# KA8yhrd-ClVYMyOefXdVYg    $$  +16036433321  (603) 643-3321
# 5WW4g_LRwau29KyjZGLyAA   NaN  +16036435134  (603) 643-5134
# neBEWvgHNhsXIBImCYx_6A    $$  +16036434075  (603) 643-4075
# 34j_2nRCVQBTKafJvncZlg   $$$  +16036468000  (603) 646-8000

# %%
# change location
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "restaurants"

my_location_tpe = "Taipei,Taiwan,03456"
yelp_genquery_tpe = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location_tpe)

## use requests to call the API
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp_tpe = requests.get(yelp_genquery_tpe, headers = header)
yelp_genresp_tpe

yelp_genresp_tpe.json()
# Out:
# <Response [200]>
# {'businesses': [{'id': '5gNHAIyajmJ_4i5vXwOVRw',
#    'alias': '永和豆漿大王-大安區-2',
#    'name': 'Yong He Soy Milk King',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/wXiJOju-YwgwdpYuzm2D1A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E6%B0%B8%E5%92%8C%E8%B1%86%E6%BC%BF%E5%A4%A7%E7%8E%8B-%E5%A4%A7%E5%AE%89%E5%8D%80-2?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 238,
#    'categories': [{'alias': 'breakfast_brunch', 'title': 'Breakfast & Brunch'},
#     {'alias': 'gourmet', 'title': 'Specialty Food'},
#     {'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.029722, 'longitude': 121.543248},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '復興南路二段102號',
#     'address2': '1樓',
#     'address3': None,
#     'city': "Da'an District",
#     'zip_code': '106',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['1/F, No. 102, Section 2, Fuxing S Road',
#      '復興南路二段102號1樓',
#      "Da'an District, 台北市 106",
#      'Taiwan']},
#    'phone': '+886227035051',
#    'display_phone': '+886 2 2703 5051',
#    'distance': 3951.9115083045726},
#   {'id': 'Xbmdhb5PEfbAPNxzghWCRQ',
#    'alias': '上引水產-中山區',
#    'name': 'Addiction Aquatic Development',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/tvdcWpOCE9GCli8mhM9xRw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E4%B8%8A%E5%BC%95%E6%B0%B4%E7%94%A2-%E4%B8%AD%E5%B1%B1%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 428,
#    'categories': [{'alias': 'seafood', 'title': 'Seafood'},
#     {'alias': 'bbq', 'title': 'Barbeque'},
#     {'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.066673, 'longitude': 121.537108},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '民族東路410巷2弄18號',
#     'address2': None,
#     'address3': None,
#     'city': 'Zhongshan District',
#     'zip_code': '104',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['No. 18, Alley 2, Lane 410, Minzu East Road',
#      '民族東路410巷2弄18號',
#      'Zhongshan District, 台北市 104',
#      'Taiwan']},
#    'phone': '+886225081268',
#    'display_phone': '+886 2 2508 1268',
#    'distance': 6239.917200628295},
#   {'id': 'amkJ0B_3RxBUA4Zh-cG-ag',
#    'alias': '麥而美早餐店-台北市萬華區',
#    'name': '麥而美早餐店',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/EyXxN18eSrbW6zlMWgpedQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E9%BA%A5%E8%80%8C%E7%BE%8E%E6%97%A9%E9%A4%90%E5%BA%97-%E5%8F%B0%E5%8C%97%E5%B8%82%E8%90%AC%E8%8F%AF%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 4,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.043388, 'longitude': 121.503893},
#    'transactions': [],
#    'location': {'address1': '成都路119號',
#     'address2': None,
#     'address3': None,
#     'city': 'Wanhua District',
#     'zip_code': '108',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['No. 119, Chengdu Road',
#      '成都路119號',
#      'Wanhua District, 台北市 108',
#      'Taiwan']},
#    'phone': '+886223315064',
#    'display_phone': '+886 2 2331 5064',
#    'distance': 2828.2807811953994},
#   {'id': 'TexN3c8guzJoyOVdD5kAOA',
#    'alias': '原西園橋下-萬華區',
#    'name': '原西園橋下',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/NSJblBlrTCDI34LjtxgYlQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E5%8E%9F%E8%A5%BF%E5%9C%92%E6%A9%8B%E4%B8%8B-%E8%90%AC%E8%8F%AF%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 5,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 25.03473, 'longitude': 121.49879},
#    'transactions': [],
#    'location': {'address1': '西園路一段242號',
#     'address2': '',
#     'address3': None,
#     'city': 'Wanhua District',
#     'zip_code': '108',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['No. 242, Section 1, Xiyuan Road',
#      '西園路一段242號',
#      'Wanhua District, 台北市 108',
#      'Taiwan']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2000.5301419425452},
#   {'id': 'YlTyBzagifcasFA0n8OpkQ',
#    'alias': '金峰魯肉飯-中正區',
#    'name': 'Jin Feng Braised Pork Rice',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/MDr0IWJbKS7yFTUQu1Wrig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E9%87%91%E5%B3%B0%E9%AD%AF%E8%82%89%E9%A3%AF-%E4%B8%AD%E6%AD%A3%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 158,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.032046, 'longitude': 121.518483},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '羅斯福路一段10-1號',
#     'address2': None,
#     'address3': None,
#     'city': 'Zhongzheng District',
#     'zip_code': '100',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['No. 10-1, Section 1, Roosevelt Rd',
#      '羅斯福路一段10-1號',
#      'Zhongzheng District, 台北市 100',
#      'Taiwan']},
#    'phone': '+886223960808',
#    'display_phone': '+886 2 2396 0808',
#    'distance': 1988.9785665598697},
#   {'id': 'PKkiynD7fcFqM38T4e52Ng',
#    'alias': '馬辣-萬華區-2',
#    'name': 'Mala Spicy Hot Pot',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/chnQH6U--Hp5yQgGZfrjrQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E9%A6%AC%E8%BE%A3-%E8%90%AC%E8%8F%AF%E5%8D%80-2?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 56,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'},
#     {'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'rating': 4.5,
#    'coordinates': {'latitude': 25.043501, 'longitude': 121.506295},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '西寧南路157號',
#     'address2': '2樓',
#     'address3': None,
#     'city': 'Wanhua District',
#     'zip_code': '108',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['2/F, No. 157, Xining Road',
#      '西寧南路157號2樓',
#      'Wanhua District, 台北市 108',
#      'Taiwan']},
#    'phone': '+886223146528',
#    'display_phone': '+886 2 2314 6528',
#    'distance': 2831.2469071952464},
#   {'id': '8Qbbb9EaqdTaAI09WQuIzA',
#    'alias': '阜杭豆漿-中正區',
#    'name': 'Fuhang Soy Milk',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/cRtE2tptTBKu49zJ-2q3OA/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E9%98%9C%E6%9D%AD%E8%B1%86%E6%BC%BF-%E4%B8%AD%E6%AD%A3%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 429,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 25.044041, 'longitude': 121.524859},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '忠孝東路一段108號',
#     'address2': '2樓',
#     'address3': None,
#     'city': 'Zhongzheng District',
#     'zip_code': '100',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['2/F-28, No. 108, Section 1, Zhongxiao East Road',
#      '忠孝東路一段108號2樓',
#      'Zhongzheng District, 台北市 100',
#      'Taiwan']},
#    'phone': '+886223922175',
#    'display_phone': '+886 2 2392 2175',
#    'distance': 3448.402039442816},
#   {'id': 'tskLWpQounhC65HgGgOFOA',
#    'alias': '饞食坊-大安區',
#    'name': 'Zen Food',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/7a3lWTY1bWJa8Mb-WuKn7g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E9%A5%9E%E9%A3%9F%E5%9D%8A-%E5%A4%A7%E5%AE%89%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 27,
#    'categories': [{'alias': 'gastropubs', 'title': 'Gastropubs'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 25.03265, 'longitude': 121.54402},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '信義路四段30巷8弄13之1號',
#     'address2': '',
#     'address3': '',
#     'city': "Da'an District",
#     'zip_code': '106',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['No. 13-1, Alley 8, Lane 30, Section 4, Xinyi Road',
#      '信義路四段30巷8弄13之1號',
#      "Da'an District, 台北市 106",
#      'Taiwan']},
#    'phone': '+886227555859',
#    'display_phone': '+886 2 2755 5859',
#    'distance': 4149.776627984837},
#   {'id': 'q0wVJRe9oMmkQ76eIyWmzQ',
#    'alias': '西門金峰-台北市萬華區',
#    'name': 'Xi Men Jin Feng',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Dh7W4r2TWZquRxJEcdTsWQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E8%A5%BF%E9%96%80%E9%87%91%E5%B3%B0-%E5%8F%B0%E5%8C%97%E5%B8%82%E8%90%AC%E8%8F%AF%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 9,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 25.042613, 'longitude': 121.504824},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '昆明街89號',
#     'address2': None,
#     'address3': None,
#     'city': 'Wanhua District',
#     'zip_code': '108',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['No. 89, Kunming Street',
#      '昆明街89號',
#      'Wanhua District, 台北市 108',
#      'Taiwan']},
#    'phone': '+886223812561',
#    'display_phone': '+886 2 2381 2561',
#    'distance': 2736.0345279584453},
#   {'id': 'fOrQH7TkRtKI882y4Ocfyg',
#    'alias': '無老鍋-中山區',
#    'name': 'Wulao',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/4apcq1HzMptQrw7Ysg7bcw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E7%84%A1%E8%80%81%E9%8D%8B-%E4%B8%AD%E5%B1%B1%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 19,
#    'categories': [{'alias': 'hotpot', 'title': 'Hot Pot'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 25.0543917916686,
#     'longitude': 121.522768296692},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '中山北路二段36-1號',
#     'address2': '',
#     'address3': '',
#     'city': 'Zhongshan District',
#     'zip_code': '104',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['No. 36-1, Section 2, Zhongshan North Road',
#      '中山北路二段36-1號',
#      'Zhongshan District, 台北市 104',
#      'Taiwan']},
#    'phone': '+886225816238',
#    'display_phone': '+886 2 2581 6238',
#    'distance': 4373.102313404266},
#   {'id': '-t40MSBQrGyEsrmWc1e-zQ',
#    'alias': '豪大大雞排-萬華區',
#    'name': 'Hot-Star Large Fried Chicken',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/AXxoB5gwdhAYo79-eulLLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E8%B1%AA%E5%A4%A7%E5%A4%A7%E9%9B%9E%E6%8E%92-%E8%90%AC%E8%8F%AF%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 52,
#    'categories': [{'alias': 'chickenshop', 'title': 'Chicken Shop'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 25.0447216609204,
#     'longitude': 121.507475976121},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '漢中街121-1號',
#     'address2': '',
#     'address3': '',
#     'city': 'Wanhua District',
#     'zip_code': '108',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['No. 121-1, Hanzhong Street',
#      '漢中街121-1號',
#      'Wanhua District, 台北市 108',
#      'Taiwan']},
#    'phone': '',
#    'display_phone': '',
#    'distance': 2969.7233816298917},
#   {'id': 'Smu2CQeGeGnPnqxVmaAejg',
#    'alias': '湯包-萬華區',
#    'name': 'Soup Dumplings',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/QkfgdCazdnS__UzW2QntaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E6%B9%AF%E5%8C%85-%E8%90%AC%E8%8F%AF%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 11,
#    'categories': [{'alias': 'dimsum', 'title': 'Dim Sum'}],
#    'rating': 4.2,
#    'coordinates': {'latitude': 25.0411901371377,
#     'longitude': 121.504528070556},
#    'transactions': [],
#    'location': {'address1': '昆明街137號',
#     'address2': '',
#     'address3': None,
#     'city': 'Wanhua District',
#     'zip_code': '108',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['No. 137, Kunming St',
#      '昆明街137號',
#      'Wanhua District, 台北市 108',
#      'Taiwan']},
#    'phone': '+886223717762',
#    'display_phone': '+886 2 2371 7762',
#    'distance': 2579.8186637431977},
#   {'id': 'hmU5HsTwnt-a9yTztYEe0Q',
#    'alias': '魚港生猛海鮮料理-板橋區',
#    'name': 'Yu Kang Seafood',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/x6Vnfm7nAZirYfFHVo3S7A/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E9%AD%9A%E6%B8%AF%E7%94%9F%E7%8C%9B%E6%B5%B7%E9%AE%AE%E6%96%99%E7%90%86-%E6%9D%BF%E6%A9%8B%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 1,
#    'categories': [{'alias': 'chinese', 'title': 'Chinese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 25.013163, 'longitude': 121.479182},
#    'transactions': [],
#    'location': {'address1': '三民路二段205號',
#     'address2': '',
#     'address3': None,
#     'city': '板橋區',
#     'zip_code': '220',
#     'country': 'TW',
#     'state': 'TPQ',
#     'display_address': ['No. 205, Section 2, Sanmin Road',
#      '三民路二段205號',
#      '板橋區, 新北市 220',
#      'Taiwan']},
#    'phone': '+886229569090',
#    'display_phone': '+886 2 2956 9090',
#    'distance': 2776.4536396710246},
#   {'id': '16bALTXEdqW77FEQ-DPjQw',
#    'alias': '21號鵝肉海鮮-中山區',
#    'name': 'Goose 21',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/S2LDbZktRiz1QSPvN3_Afw/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/21%E8%99%9F%E9%B5%9D%E8%82%89%E6%B5%B7%E9%AE%AE-%E4%B8%AD%E5%B1%B1%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 6,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'},
#     {'alias': 'seafood', 'title': 'Seafood'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 25.0602793984662,
#     'longitude': 121.525171431503},
#    'transactions': [],
#    'price': '$',
#    'location': {'address1': '錦州街21號',
#     'address2': '',
#     'address3': '',
#     'city': 'Zhongshan District',
#     'zip_code': '104',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['No. 21, Jinzhou Street',
#      '錦州街21號',
#      'Zhongshan District, 台北市 104',
#      'Taiwan']},
#    'phone': '+886225362121',
#    'display_phone': '+886 2 2536 2121',
#    'distance': 5070.671925130453},
#   {'id': 'A9E6hvrLE94BlrXkE2h7lg',
#    'alias': '大腕燒肉專門店-台北市大安區',
#    'name': 'Da-Wan Yakiniku Dining Restaurant',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/W42mV8L9NgaIBney3GDpCQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E5%A4%A7%E8%85%95%E7%87%92%E8%82%89%E5%B0%88%E9%96%80%E5%BA%97-%E5%8F%B0%E5%8C%97%E5%B8%82%E5%A4%A7%E5%AE%89%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 57,
#    'categories': [{'alias': 'yakiniku', 'title': 'Yakiniku'}],
#    'rating': 4.7,
#    'coordinates': {'latitude': 25.042974, 'longitude': 121.550236},
#    'transactions': [],
#    'price': '$$$',
#    'location': {'address1': '敦化南路一段177巷22號',
#     'address2': None,
#     'address3': None,
#     'city': "Da'an District",
#     'zip_code': '106',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['No. 22, Lane 177, Section 1, Dunhua South Road',
#      '敦化南路一段177巷22號',
#      "Da'an District, 台北市 106",
#      'Taiwan']},
#    'phone': '+886227110179',
#    'display_phone': '+886 2 2711 0179',
#    'distance': 5231.333684908177},
#   {'id': 'ypo-zYVA1Zeur0kztrDfdA',
#    'alias': 'sunny-buffet-松山區',
#    'name': 'Sunny Buffet',
#    'image_url': 'https://s3-media2.fl.yelpcdn.com/bphoto/Yf64zmkqj385wWmVVCvKLQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/sunny-buffet-%E6%9D%BE%E5%B1%B1%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 4,
#    'categories': [{'alias': 'buffets', 'title': 'Buffets'}],
#    'rating': 4.3,
#    'coordinates': {'latitude': 25.052432, 'longitude': 121.548411},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '敦化北路100號',
#     'address2': '1樓',
#     'address3': None,
#     'city': 'Songshan District',
#     'zip_code': '105',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['1/F, No. 100, Dunhua North Road',
#      '敦化北路100號1樓',
#      'Songshan District, 台北市 105',
#      'Taiwan']},
#    'phone': '+886227197199',
#    'display_phone': '+886 2 2719 7199',
#    'distance': 5718.8970083024915},
#   {'id': 'mRTk6tiDKVI2MrbXzwwhQQ',
#    'alias': '梅子餐廳-台北市中山區',
#    'name': 'Umeko Restaurant',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/IxOVeNJejjPTLJx5oW81Wg/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E6%A2%85%E5%AD%90%E9%A4%90%E5%BB%B3-%E5%8F%B0%E5%8C%97%E5%B8%82%E4%B8%AD%E5%B1%B1%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 9,
#    'categories': [{'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'rating': 4.8,
#    'coordinates': {'latitude': 25.050293, 'longitude': 121.525245},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '林森北路107巷1號',
#     'address2': None,
#     'address3': None,
#     'city': 'Zhongshan District',
#     'zip_code': '104',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['No. 1, Lane 107, Linsen North Road',
#      '林森北路107巷1號',
#      'Zhongshan District, 台北市 104',
#      'Taiwan']},
#    'phone': '+886225213200',
#    'display_phone': '+886 2 2521 3200',
#    'distance': 4067.2154115631192},
#   {'id': 'XnPJfiLtarZZdepBksPObQ',
#    'alias': '西門靖-萬華區-2',
#    'name': '西門靖',
#    'image_url': 'https://s3-media4.fl.yelpcdn.com/bphoto/19xqsbU80vYva1y8e-VXaQ/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E8%A5%BF%E9%96%80%E9%9D%96-%E8%90%AC%E8%8F%AF%E5%8D%80-2?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 5,
#    'categories': [{'alias': 'japanese', 'title': 'Japanese'},
#     {'alias': 'bbq', 'title': 'Barbeque'}],
#    'rating': 4.4,
#    'coordinates': {'latitude': 25.045299, 'longitude': 121.50402},
#    'transactions': [],
#    'price': '$$',
#    'location': {'address1': '武昌街二段122號',
#     'address2': '1樓',
#     'address3': None,
#     'city': 'Wanhua District',
#     'zip_code': '108',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['武昌街二段122號',
#      '1樓',
#      'Wanhua District, 台北市 108',
#      'Taiwan']},
#    'phone': '+886223888876',
#    'display_phone': '+886 2 2388 8876',
#    'distance': 3039.1482062192},
#   {'id': 'in0JTjLQnDlWIBLJIZArxg',
#    'alias': '牛肉麵-雞湯-松山區-2',
#    'name': 'Taiwan Beef Noodles·Chicken Soup',
#    'image_url': 'https://s3-media3.fl.yelpcdn.com/bphoto/Kh-t0slivdCf336PCgTfig/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E7%89%9B%E8%82%89%E9%BA%B5-%E9%9B%9E%E6%B9%AF-%E6%9D%BE%E5%B1%B1%E5%8D%80-2?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 5,
#    'categories': [{'alias': 'noodles', 'title': 'Noodles'},
#     {'alias': 'taiwanese', 'title': 'Taiwanese'}],
#    'rating': 4.6,
#    'coordinates': {'latitude': 25.045278, 'longitude': 121.54752},
#    'transactions': [],
#    'location': {'address1': '市民大道四段85號',
#     'address2': '',
#     'address3': None,
#     'city': 'Songshan District',
#     'zip_code': '105',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['No. 85, Section 4, Civic Blvd',
#      '市民大道四段85號',
#      'Songshan District, 台北市 105',
#      'Taiwan']},
#    'phone': '+886227787776',
#    'display_phone': '+886 2 2778 7776',
#    'distance': 5147.802702346086},
#   {'id': '3DCk85grgYKRNwtmcBI29w',
#    'alias': '永和豆漿-信義區-3',
#    'name': '永和豆漿',
#    'image_url': 'https://s3-media1.fl.yelpcdn.com/bphoto/J9Y4ZS8IJ1t4F2noQVFX4g/o.jpg',
#    'is_closed': False,
#    'url': 'https://www.yelp.com/biz/%E6%B0%B8%E5%92%8C%E8%B1%86%E6%BC%BF-%E4%BF%A1%E7%BE%A9%E5%8D%80-3?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_search&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'review_count': 1,
#    'categories': [{'alias': 'breakfast_brunch',
#      'title': 'Breakfast & Brunch'}],
#    'rating': 5.0,
#    'coordinates': {'latitude': 25.02288, 'longitude': 121.55437},
#    'transactions': [],
#    'location': {'address1': '和平東路三段241號',
#     'address2': None,
#     'address3': '',
#     'city': 'Xinyi District',
#     'zip_code': '110',
#     'country': 'TW',
#     'state': 'TPE',
#     'display_address': ['No. 241, Section 3, Heping East Road',
#      '和平東路三段241號',
#      'Xinyi District, 台北市 110',
#      'Taiwan']},
#    'phone': '+886287322767',
#    'display_phone': '+886 2 8732 2767',
#    'distance': 4882.982239820941}],
#  'total': 8300,
#  'region': {'center': {'longitude': 121.50604248046875,
#    'latitude': 25.017850033436694}}}

# %%
yelp_genjson_tpe = yelp_genresp_tpe.json()

## turn JSON into usable data (DF)
yelp_gendf = pd.DataFrame(yelp_genjson_tpe['businesses'])
#list(yelp_gendf_marlow) # list columns
yelp_gendf['location1'] = yelp_gendf.location.apply(lambda loclist: loclist['address1'])
yelp_gendf[['alias', 'name', 'url', 'review_count', 'rating', 'location1', 'price']]
# Out:
#                alias                               name  \
# 0       永和豆漿大王-大安區-2              Yong He Soy Milk King
# 1           上引水產-中山區      Addiction Aquatic Development
# 2      麥而美早餐店-台北市萬華區                             麥而美早餐店
# 3          原西園橋下-萬華區                              原西園橋下
# 4           阜杭豆漿-中正區                    Fuhang Soy Milk
# 5          金峰魯肉飯-中正區         Jin Feng Braised Pork Rice
# 6     大腕燒肉專門店-台北市大安區  Da-Wan Yakiniku Dining Restaurant
# 7           馬辣-萬華區-2                 Mala Spicy Hot Pot
# 8        西門金峰-台北市萬華區                    Xi Men Jin Feng
# 9          豪大大雞排-萬華區       Hot-Star Large Fried Chicken
# 10  sunny-buffet-松山區                       Sunny Buffet
# 11           饞食坊-大安區                           Zen Food
# 12          欣葉-中山區-3                           Shin Yeh
# 13           無老鍋-中山區                              Wulao
# 14      劉媽媽飯糰-台北市中正區               Liu Mama’s Rice Ball
# 15         新港茶餐廳-萬華區           New Hong Kong Restaurant
# 16           鼎泰豐-板橋區                       Din Tai Fung
# 17          饗食天堂-大同區                         Eatogether
# 18     永康牛肉麺館-台北市大安區             Yong Kang Beef Noodles
# 19    萬華陳記專業腸蚵麵線-萬華區                         萬華陳記專業腸蚵麵線
#
#                                                   url  review_count  rating  \
# 0   https://www.yelp.com/biz/%E6%B0%B8%E5%92%8C%E8...           238     4.4
# 1   https://www.yelp.com/biz/%E4%B8%8A%E5%BC%95%E6...           428     4.3
# 2   https://www.yelp.com/biz/%E9%BA%A5%E8%80%8C%E7...             4     4.3
# 3   https://www.yelp.com/biz/%E5%8E%9F%E8%A5%BF%E5...             5     4.8
# 4   https://www.yelp.com/biz/%E9%98%9C%E6%9D%AD%E8...           429     4.2
# 5   https://www.yelp.com/biz/%E9%87%91%E5%B3%B0%E9...           158     4.3
# 6   https://www.yelp.com/biz/%E5%A4%A7%E8%85%95%E7...            57     4.7
# 7   https://www.yelp.com/biz/%E9%A6%AC%E8%BE%A3-%E...            56     4.5
# 8   https://www.yelp.com/biz/%E8%A5%BF%E9%96%80%E9...             9     4.2
# 9   https://www.yelp.com/biz/%E8%B1%AA%E5%A4%A7%E5...            52     4.2
# 10  https://www.yelp.com/biz/sunny-buffet-%E6%9D%B...             4     4.3
# 11  https://www.yelp.com/biz/%E9%A5%9E%E9%A3%9F%E5...            27     4.6
# 12  https://www.yelp.com/biz/%E6%AC%A3%E8%91%89-%E...            46     4.3
# 13  https://www.yelp.com/biz/%E7%84%A1%E8%80%81%E9...            19     4.7
# 14  https://www.yelp.com/biz/%E5%8A%89%E5%AA%BD%E5...            14     4.6
# 15  https://www.yelp.com/biz/%E6%96%B0%E6%B8%AF%E8...             8     4.5
# 16  https://www.yelp.com/biz/%E9%BC%8E%E6%B3%B0%E8...            34     4.4
# 17  https://www.yelp.com/biz/%E9%A5%97%E9%A3%9F%E5...            18     4.4
# 18  https://www.yelp.com/biz/%E6%B0%B8%E5%BA%B7%E7...           273     4.0
# 19  https://www.yelp.com/biz/%E8%90%AC%E8%8F%AF%E9...            14     4.6
#
#           location1 price
# 0        復興南路二段102號     $
# 1     民族東路410巷2弄18號    $$
# 2           成都路119號   NaN
# 3         西園路一段242號   NaN
# 4        忠孝東路一段108號     $
# 5       羅斯福路一段10-1號     $
# 6     敦化南路一段177巷22號   $$$
# 7          西寧南路157號    $$
# 8            昆明街89號     $
# 9         漢中街121-1號     $
# 10         敦化北路100號    $$
# 11  信義路四段30巷8弄13之1號    $$
# 12         雙城街34-1號    $$
# 13      中山北路二段36-1號    $$
# 14        杭州南路二段88號     $
# 15           漢中街52號   NaN
# 16           新站路28號    $$
# 17          承德路一段1號   $$$
# 18     金山南路二段31巷17號    $$
# 19       和平西路三段166號     $

# %%
# change location
base_url = "https://api.yelp.com/v3/businesses/search?"
my_name = "restaurants"

my_location_tpe = "Pacific Palisades, 90272"
yelp_genquery_tpe = ('{base_url}'
                'term={name}'
                '&location={loc}').format(base_url = base_url,
                name = my_name,
                loc = my_location_tpe)

## use requests to call the API
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp_tpe = requests.get(yelp_genquery_tpe, headers = header)
# yelp_genresp_tpe

# yelp_genresp_tpe.json()

yelp_genjson_tpe = yelp_genresp_tpe.json()

## turn JSON into usable data (DF)
yelp_gendf = pd.DataFrame(yelp_genjson_tpe['businesses'])
#list(yelp_gendf_marlow) # list columns
yelp_gendf['location1'] = yelp_gendf.location.apply(lambda loclist: loclist['address1'])
yelp_gendf[['alias', 'name', 'url', 'review_count', 'rating', 'location1', 'price']]
# Out:
#                                                 alias  \
# 0             palisades-garden-cafe-pacific-palisades
# 1        spruzzo-restaurant-and-bar-pacific-palisades
# 2                       cafe-vida-pacific-palisades-2
# 3                                   armav-los-angeles
# 4         juicy-ladies-organic-cafe-pacific-palisades
# 5                      gladstones-pacific-palisades-4
# 6                           prima-cantina-los-angeles
# 7                                 hanks-los-angeles-2
# 8                        moku-sushi-pacific-palisades
# 9             angelini-ristorante-and-bar-los-angeles
# 10             matthews-garden-cafe-pacific-palisades
# 11                          casa-nostra-los-angeles-3
# 12                  beach-side-cafe-pacific-palisades
# 13                           neto-s-cafe-santa-monica
# 14                        que-padre-pacific-palisades
# 15                                muse-santa-monica-2
# 16       k-bakery-eatery-bakeshop-pacific-palisades-2
# 17                     fiesta-feast-pacific-palisades
# 18                     pearl-dragon-pacific-palisades
# 19  blue-ribbon-sushi-pacific-palisades-pacific-pa...
#
#                                      name  \
# 0                   Palisades Garden Cafe
# 1                Spruzzo Restaurant & Bar
# 2                               Cafe Vida
# 3                                   Armav
# 4                            Juicy Ladies
# 5                              Gladstones
# 6                           Prima Cantina
# 7                                  Hank's
# 8                              Moku Sushi
# 9               Angelini Ristorante & Bar
# 10                  Matthew's Garden Cafe
# 11                            Casa Nostra
# 12                        Beach Side Cafe
# 13                            Neto’s Cafe
# 14                              Que Padre
# 15                                   Muse
# 16             K Bakery Eatery + Bakeshop
# 17                           Fiesta Feast
# 18                           Pearl Dragon
# 19  Blue Ribbon Sushi - Pacific Palisades
#
#                                                   url  review_count  rating  \
# 0   https://www.yelp.com/biz/palisades-garden-cafe...           315     4.2
# 1   https://www.yelp.com/biz/spruzzo-restaurant-an...            78     4.6
# 2   https://www.yelp.com/biz/cafe-vida-pacific-pal...           853     4.4
# 3   https://www.yelp.com/biz/armav-los-angeles?adj...            85     4.7
# 4   https://www.yelp.com/biz/juicy-ladies-organic-...           301     4.0
# 5   https://www.yelp.com/biz/gladstones-pacific-pa...          2447     3.0
# 6   https://www.yelp.com/biz/prima-cantina-los-ang...            38     3.7
# 7   https://www.yelp.com/biz/hanks-los-angeles-2?a...           321     3.6
# 8   https://www.yelp.com/biz/moku-sushi-pacific-pa...           229     4.3
# 9   https://www.yelp.com/biz/angelini-ristorante-a...           106     3.7
# 10  https://www.yelp.com/biz/matthews-garden-cafe-...           368     3.9
# 11  https://www.yelp.com/biz/casa-nostra-los-angel...            33     4.6
# 12  https://www.yelp.com/biz/beach-side-cafe-pacif...            24     3.0
# 13  https://www.yelp.com/biz/neto-s-cafe-santa-mon...            17     4.9
# 14  https://www.yelp.com/biz/que-padre-pacific-pal...            97     3.8
# 15  https://www.yelp.com/biz/muse-santa-monica-2?a...            44     4.9
# 16  https://www.yelp.com/biz/k-bakery-eatery-bakes...           112     4.1
# 17  https://www.yelp.com/biz/fiesta-feast-pacific-...           174     3.8
# 18  https://www.yelp.com/biz/pearl-dragon-pacific-...           236     3.9
# 19  https://www.yelp.com/biz/blue-ribbon-sushi-pac...           128     3.9
#
#                      location1 price
# 0             15231 La Cruz Dr     $
# 1             538 Palisades Dr   NaN
# 2             15317 Antioch St    $$
# 3              970 Monument St   NaN
# 4            17361 Sunset Blvd   $$$
# 5      17300 Pacific Coast Hwy  $$$$
# 6          15246 W Sunset Blvd   NaN
# 7        1033 N Swarthmore Ave    $$
# 8             524 Palisades Dr    $$
# 9        1038 N Swarthmore Ave   $$$
# 10      859 1/2 Swarthmore Ave    $$
# 11           15306 Sunset Blvd   NaN
# 12     15700 Pacific Coast Hwy    $$
# 13            169 W Channel Rd   NaN
# 14  15225 Palisades Village Ln   NaN
# 15            108 W Channel Rd   NaN
# 16            548 Palisades Dr    $$
# 17         17336 W Sunset Blvd     $
# 18         15229 W Sunset Blvd    $$
# 19  15201 Palisades Village Ln   NaN

# %% [markdown]
# # Activity 2: pull restaurants in a different location
#
# - Try running a business search query for your hometown or another place by constructing a query similar to `yelp_genquery` but changing the location parameter
# - Other endpoints require feeding what's called the business' fusion id into the API. Take an id from `yelp_stronly.id` and use the documentation here to pull the reviews for that business: https://docs.developer.yelp.com/reference/v3_business_reviews
# - **Challenge**: generalize the previous step by writing a function that (1) takes a list of business ids as an input, (2) calls the reviews API for each id, (3) returns the results, and (4) rowbinds all results, i.e. turns them into a single, usable DataFrame

# %%
# your code here

# %%
# look at reviews of business with this id
base_url_reviews = f'https://api.yelp.com/v3/businesses/{biz_id}/reviews'
yelp_genquery_reviews = (base_url_reviews)

## use requests to call the API
header = {'Authorization': f"Bearer {API_KEY}"}
yelp_genresp_reviews = requests.get(yelp_genquery_reviews, headers = header)
yelp_genresp_reviews

## then, look at structure of response
yelp_genjson_reviews = yelp_genresp_reviews.json()
yelp_genjson_reviews
# Out:
# <Response [200]>
# {'reviews': [{'id': '8vZyIz2hl6GcjazfvPTaSA',
#    'url': 'https://www.yelp.com/biz/%E4%B8%8A%E5%BC%95%E6%B0%B4%E7%94%A2-%E4%B8%AD%E5%B1%B1%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=8vZyIz2hl6GcjazfvPTaSA&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'text': 'This one of our top meals on our trip to Taiwan.\n\nExcellent service, beautiful place, accompanied by some of the freshest, best tasting seafood you can...',
#    'rating': 5,
#    'time_created': '2025-01-11 00:18:17',
#    'user': {'id': 'rhnFDusn-D-fDu3DeyY2kQ',
#     'profile_url': 'https://www.yelp.com/user_details?userid=rhnFDusn-D-fDu3DeyY2kQ',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/MCERkNe7zxLyM2QQ19pFkQ/o.jpg',
#     'name': 'Felix G.'}},
#   {'id': 'urVeePoK7c4WL4UfDfGDiQ',
#    'url': 'https://www.yelp.com/biz/%E4%B8%8A%E5%BC%95%E6%B0%B4%E7%94%A2-%E4%B8%AD%E5%B1%B1%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=urVeePoK7c4WL4UfDfGDiQ&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'text': 'An incredible spot with a massive section of tanks filled with fresh, live seafood. There are more than a handful of king crab tanks, along with tons of...',
#    'rating': 5,
#    'time_created': '2024-12-31 02:12:10',
#    'user': {'id': 'J4kNEWYAfS69Jb0nkIGFbg',
#     'profile_url': 'https://www.yelp.com/user_details?userid=J4kNEWYAfS69Jb0nkIGFbg',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/YYj6k26rHekJVO5lADugzg/o.jpg',
#     'name': 'William S.'}},
#   {'id': 'rNeJa7_Zk1BSc2eKXWXqkg',
#    'url': 'https://www.yelp.com/biz/%E4%B8%8A%E5%BC%95%E6%B0%B4%E7%94%A2-%E4%B8%AD%E5%B1%B1%E5%8D%80?adjust_creative=AYAiHNSGxz_RRHzq3cO46w&hrid=rNeJa7_Zk1BSc2eKXWXqkg&utm_campaign=yelp_api_v3&utm_medium=api_v3_business_reviews&utm_source=AYAiHNSGxz_RRHzq3cO46w',
#    'text': '*** Cash only & restrooms available ***\n\nAddiction Aquatic Development (AAD) is the most-reviewed establishment on Yelp in the entire Taiwan. Interestingly...',
#    'rating': 4,
#    'time_created': '2024-12-01 14:41:29',
#    'user': {'id': 'rQLEfpfSjVK-3dBmIMKZDA',
#     'profile_url': 'https://www.yelp.com/user_details?userid=rQLEfpfSjVK-3dBmIMKZDA',
#     'image_url': 'https://s3-media2.fl.yelpcdn.com/photo/rR2hvEJm4Vzb3ShTbwpKfg/o.jpg',
#     'name': 'Luke L.'}}],
#  'total': 428,
#  'possible_languages': ['zh', 'en']}
